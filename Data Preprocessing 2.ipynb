# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\satya\Desktop\python\Python for data analysis\scriptsLecture\section5\endangeredLang.csv')

# %%
data.shape
# Out:
# (2722, 9)

# %%
data.head(5)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
# 4                      ITA, CHE  Definitely endangered           3500000.0
#
# ...

# %%
data.drop(data.index[0],inplace=True)
data.head(3)
# Out:
#     ID Name in English                                          Countries  \
# 2  383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3  335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4  382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
# 4                      ITA, CHE  Definitely endangered           3500000.0
#
#    Latitude  Longitude                        Description of the location
# 2   53.4029    10.3601  northern Germany, the north-eastern part of th...
# 3   53.9560    27.5756  Belarus except the Polesian-speaking south-wes...
# 4   45.7215     9.3273  the region of Lombardy (except the southernmos...

# %%
data.drop(["Countries"], axis=1, inplace=False)
# Out:
#         ID    Name in English         Country codes alpha 3  \
# 0     1022      South Italian                           ITA
# 1     1023           Sicilian                           ITA
# 2      383          Low Saxon       DEU, DNK, NLD, POL, RUS
# 3      335         Belarusian  BRB, LVA, LTU, POL, RUS, UKR
# 4      382            Lombard                      ITA, CHE
# ...    ...                ...                           ...
# 2717  1972           Yonaguni                           JPN
# 2718  2018             Yucuna                           COL
# 2719  2015  Yurutí (Colombia)                           COL
# 2720  2716          Zangskari                      IND, PAK
# 2721  2177            Zidgali                           OMN
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 0                Vulnerable           7500000.0   40.9798    15.2490
# 1                Vulnerable           5000000.0   37.4399    14.5019
# ...

# %% [markdown]
# ## Indexing and Slicing

# %%
data.iloc[:3,:9]
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
#
#      Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                      ITA             Vulnerable           7500000.0
# 1                      ITA             Vulnerable           5000000.0
# 2  DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
#
#    Latitude  Longitude                        Description of the location
# 0   40.9798    15.2490  Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 1   37.4399    14.5019  Sicily (Sicilia), southern and central Calabri...
# 2   53.4029    10.3601  northern Germany, the north-eastern part of th...

# %%
data1 = data.loc[:,["Countries",'Latitude']]

# %%
data1
# Out:
#                                               Countries  Latitude
# 0                                                 Italy   40.9798
# 1                                                 Italy   37.4399
# 2     Germany, Denmark, Netherlands, Poland, Russian...   53.4029
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...   53.9560
# 4                                    Italy, Switzerland   45.7215
# ...                                                 ...       ...
# 2717                                              Japan   24.4580
# 2718                                           Colombia   -1.2633
# 2719                                           Colombia    1.1370
# 2720                                    India, Pakistan   34.0833
# 2721                                               Oman   23.4027
#
# [2722 rows x 2 columns]

# %%
data1[['Countries']][3:8]
# Out:
#                                            Countries
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India

# %%
x = data[data.Countries=='India']
x
# Out:
#         ID Name in English Countries Country codes alpha 3  \
# 7     1586           Gondi     India                   IND
# 16    1591   Kurux (India)     India                   IND
# 18    1585            Tulu     India                   IND
# 19    1556          Kangdi     India                   IND
# 26    1227         Meithei     India                   IND
# ...    ...             ...       ...                   ...
# 2607  2723            Koro     India                   IND
# 2614   537        Langrong     India                   IND
# 2622  1579           Manda     India                   IND
# 2653  1566           Padri     India                   IND
# 2699   447          Tolcha     India                   IND
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 7                Vulnerable           2713790.0   19.5804    80.4418
# 16               Vulnerable           1751489.0   22.1467    85.2758
# ...

# %%
y = data[(data.Countries=='India') | (data.Countries == 'Germany')]
y
# Out:
#         ID Name in English Countries Country codes alpha 3  \
# 7     1586           Gondi     India                   IND
# 16    1591   Kurux (India)     India                   IND
# 18    1585            Tulu     India                   IND
# 19    1556          Kangdi     India                   IND
# 26    1227         Meithei     India                   IND
# ...    ...             ...       ...                   ...
# 2607  2723            Koro     India                   IND
# 2614   537        Langrong     India                   IND
# 2622  1579           Manda     India                   IND
# 2653  1566           Padri     India                   IND
# 2699   447          Tolcha     India                   IND
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 7                Vulnerable           2713790.0   19.5804    80.4418
# 16               Vulnerable           1751489.0   22.1467    85.2758
# ...

# %%
x1 = data.loc[data['Countries'].isin(['Germany','India'])]

# %%
x1
# Out:
#         ID Name in English Countries Country codes alpha 3  \
# 7     1586           Gondi     India                   IND
# 16    1591   Kurux (India)     India                   IND
# 18    1585            Tulu     India                   IND
# 19    1556          Kangdi     India                   IND
# 26    1227         Meithei     India                   IND
# ...    ...             ...       ...                   ...
# 2607  2723            Koro     India                   IND
# 2614   537        Langrong     India                   IND
# 2622  1579           Manda     India                   IND
# 2653  1566           Padri     India                   IND
# 2699   447          Tolcha     India                   IND
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 7                Vulnerable           2713790.0   19.5804    80.4418
# 16               Vulnerable           1751489.0   22.1467    85.2758
# ...

# %%
df = data[:]

# %%
df
# Out:
#         ID    Name in English  \
# 0     1022      South Italian
# 1     1023           Sicilian
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
df.rename(columns={'Number of speakers':'Number'},inplace = True)

# %%
df
# Out:
#         ID    Name in English  \
# 0     1022      South Italian
# 1     1023           Sicilian
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
df[((df.Countries == "India") & (df.Number <100))]
# Out:
#         ID   Name in English Countries Country codes alpha 3  \
# 1912  2455              Onge     India                   IND
# 1922  1363         Sentilese     India                   IND
# 1957  1364            Jarawa     India                   IND
# 2172  2722  Great andamanese     India                   IND
# 2284   429              Ahom     India                   IND
# 2291   513             Andro     India                   IND
# 2323   519           Chairel     India                   IND
# 2477   443           Rangkas     India                   IND
# 2481   558           Sengmai     India                   IND
#
#      Degree of endangerment  Number  Latitude  Longitude  \
# 1912  Critically endangered    50.0   10.6390    92.4938
# 1922  Critically endangered    50.0   11.5446    92.2576
# 1957  Critically endangered    31.0   12.6028    92.7520
# 2172  Critically endangered     5.0   12.2326    92.9031
# 2284                Extinct     0.0   26.5393    92.5378
# ...

# %% [markdown]
# ## Basic Grouping

# %%
x11 = data.groupby(['Degree of endangerment']).count()
x11
# Out:
#                          ID  Name in English  Countries  \
# Degree of endangerment
# Critically endangered   607              607        607
# Definitely endangered   680              680        679
# Extinct                 253              253        253
# Severely endangered     554              554        554
# Vulnerable              628              628        628
#
#                         Country codes alpha 3  Number of speakers  Latitude  \
# Degree of endangerment
# Critically endangered                     607                 544       606
# Definitely endangered                     679                 635       680
# Extinct                                   253                 244       252
# Severely endangered                       554                 505       554
# Vulnerable                                628                 611       627
#
#                         Longitude  Description of the location
# Degree of endangerment
# ...

# %%
cd = data.groupby(["Countries",'Degree of endangerment']).sum()

# %%
x11 = data['Number of speakers'].groupby(data['Countries'])
x11.head(10)
# Out:
# 0       7500000.0
# 1       5000000.0
# 2       4800000.0
# 3       4000000.0
# 4       3500000.0
#           ...
# 2714          NaN
# 2716          NaN
# 2717          NaN
# 2720          NaN
# 2721          NaN
# Name: Number of speakers, Length: 955, dtype: float64

# %%
data['vfew'] = data['Number of speakers'].apply(lambda x:x <= 5000)

# %%
data.head(5)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
# 4                      ITA, CHE  Definitely endangered           3500000.0
#
# ...

# %%
data1 = data.groupby(data['vfew'])

# %%
data1.size()
# Out:
# vfew
# False     879
# True     1843
# dtype: int64

# %%
data2 = data.groupby(['vfew','Countries'])

# %%
data2.size()
# Out:
# vfew   Countries
# False  Afghanistan                                                                                                                                                                                                                                                                                                                                                                                      2
#        Albania, Algeria, Bosnia and Herzegovina, Bulgaria, Croatia, Greece, The former Yugoslav Republic of Macedonia, Morocco, Romania, Turkey, Serbia                                                                                                                                                                                                                                                 1
# ...

# %%
df[(df.Countries=='India') & (df.Number<5000)].count()
# Out:
# ID                             47
# Name in English                47
# Countries                      47
# Country codes alpha 3          47
# Degree of endangerment         47
# Number                         47
# Latitude                       47
# Longitude                      47
# Description of the location    31
# dtype: int64

# %%
df1 = df[(df.Countries == 'India')].groupby(["Degree of endangerment"]).count()

# %%
df1
# Out:
#                         ID  Name in English  Countries  Country codes alpha 3  \
# Degree of endangerment
# Critically endangered   40               40         40                     40
# Definitely endangered   45               45         45                     45
# Extinct                  6                6          6                      6
# Severely endangered      6                6          6                      6
# Vulnerable              66               66         66                     66
#
#                         Number  Latitude  Longitude  \
# Degree of endangerment
# Critically endangered       37        40         40
# Definitely endangered       42        45         45
# Extinct                      5         6          6
# Severely endangered          5         6          6
# Vulnerable                  65        66         66
#
#                         Description of the location
# Degree of endangerment
# Critically endangered                            29
# ...

# %%
df2 = df.groupby(["Degree of endangerment"]).count()

# %%
df2
# Out:
#                          ID  Name in English  Countries  \
# Degree of endangerment
# Critically endangered   607              607        607
# Definitely endangered   680              680        679
# Extinct                 253              253        253
# Severely endangered     554              554        554
# Vulnerable              628              628        628
#
#                         Country codes alpha 3  Number  Latitude  Longitude  \
# Degree of endangerment
# Critically endangered                     607     544       606        606
# Definitely endangered                     679     635       680        680
# Extinct                                   253     244       252        252
# Severely endangered                       554     505       554        554
# Vulnerable                                628     611       627        627
#
#                         Description of the location
# Degree of endangerment
# ...

# %%
x = pd.crosstab(df["Countries"],df["Degree of endangerment"],margins = True)

# %%
x
# Out:
# Degree of endangerment                              Critically endangered  \
# Countries
# Afghanistan                                                             2
# Albania, Algeria, Bosnia and Herzegovina, Bulga...                      0
# Albania, Bulgaria, Greece, The former Yugoslav ...                      0
# Albania, Bulgaria, The former Yugoslav Republic...                      0
# Albania, Germany, Austria, Belarus, Bosnia and ...                      0
# ...                                                                   ...
# Venezuela (Bolivarian Republic of)                                      7
# Viet Nam                                                                3
# Western Sahara                                                          1
# Yemen                                                                   0
# All                                                                   607
#
# ...

# %%
x.columns
# Out:
# Index(['Critically endangered', 'Definitely endangered', 'Extinct',
#        'Severely endangered', 'Vulnerable', 'All'],
#       dtype='object', name='Degree of endangerment')

# %% [markdown]
# ## Reshaping the Data

# %%
data = pd.read_csv(r"C:\Users\satya\Desktop\python\Python for data analysis\scriptsLecture\section5\endangeredLang2.csv")

# %%
data.head(4)
# Out:
#      ID   EnglishNames                                          Countries  \
# 0  1022  South Italian                                              Italy
# 1  1023       Sicilian                                              Italy
# 2   383      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
#
#                     CountryCode Endangerment         No  Latitude  Longitude
# 0                           ITA   Vulnerable  7500000.0   40.9798    15.2490
# 1                           ITA   Vulnerable  5000000.0   37.4399    14.5019
# 2       DEU, DNK, NLD, POL, RUS   Vulnerable  4800000.0   53.4029    10.3601
# 3  BRB, LVA, LTU, POL, RUS, UKR   Vulnerable  4000000.0   53.9560    27.5756

# %%
dstack = data.stack()

# %%
dstack
# Out:
# 0     ID                               1022
#       EnglishNames            South Italian
#       Countries                       Italy
#       CountryCode                       ITA
#       Endangerment               Vulnerable
#                               ...
# 2721  Countries                        Oman
#       CountryCode                       OMN
#       Endangerment    Critically endangered
#       Latitude                      23.4027
#       Longitude                     58.0957
# Length: 21585, dtype: object

# %%
dstack[1]
# Out:
# ID                    1023
# EnglishNames      Sicilian
# Countries            Italy
# CountryCode            ITA
# Endangerment    Vulnerable
# No                   5e+06
# Latitude           37.4399
# Longitude          14.5019
# dtype: object

# %%
x = dstack.unstack() #   for unstacking the data
x
# Out:
#         ID       EnglishNames  \
# 0     1022      South Italian
# 1     1023           Sicilian
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %% [markdown]
# ## Working on GlobalFirePower Dataset

# %%
data = pd.read_csv(r"C:\Users\satya\Desktop\python\Python for data analysis\scriptsLecture\section5\GlobalFirePower.csv")

# %%
data.shape
# Out:
# (133, 47)

# %%
data.sort_index(axis=1)
# Out:
#      Active Personnel  Aircraft Carriers  Armored Fighting Vehicles  \
# 0             1373650                 19                      41062
# 1              798527                  1                      31298
# 2             2260000                  1                       4788
# 3             1362500                  3                       6704
# 4              204000                  4                       6863
# ..                ...                ...                        ...
# 128              5825                  0                         51
# 129             15870                  0                         70
# 130             10750                  0                         10
# 131              2170                  0                         40
# 132              7500                  0                         10
#
#      Attack Aircraft  Attack Helicopters Coastline (km)  Combat Tanks  \
# 0               2785                 947          19924          5884
# ...

# %%
data.sort_values(by=["ISO3","Total Population"])
# Out:
#         Country ISO3  Rank  Total Population  Manpower Available  \
# 68  Afghanistan  AFG    69          33332025            14000000
# 89      Albania  ALB    90           3038594             1515000
# 24      Algeria  ALG    25          40263711            20400000
# 50       Angola  ANG    51          20172332             6030000
# 34    Argentina  ARG    35          43886748            20000000
# ..          ...  ...   ...               ...                 ...
# 44    Venezuela  VEN    45          30912302            14200000
# 15      Vietnam  VTN    16          95261021            50650000
# 63        Yemen  YEM    64          27392779            11040000
# 84       Zambia  ZAM    85          15510711             6000000
# 80     Zimbabwe  ZIM    81          14546961             5500000
#
#     Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 68          8000000                 765000                    200000
# ...

# %%
x= data.iloc[0:8,0:8]

# %%
x['TMPrank'] = data["Total Military Personnel"].rank()

# %%
x.sort_values(["TMPrank"])
# Out:
#           Country ISO3  Rank  Total Population  Manpower Available  \
# 5  United Kingdom  UKD     6          64430428            30000000
# 6           Japan  JPN     7         126702133            54000000
# 4          France  FRA     5          66836154            30000000
# 7          Turkey  TUR     8          80274604            41640000
# 0   United States  USA     1         323995528           145215000
# 1          Russia  RUS     2         142355415            70000000
# 2           China  CHN     3        1373541278           750000000
# 3           India  IND     4        1266883598           616000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  TMPrank
# 5         24040000                 750000                    232675     93.0
# 6         44000000                1215000                    311875    101.0
# 4         23750000                 775000                    387635    107.0
# ...

# %% [markdown]
# ## Concatenation

# %%
drink = pd.read_csv(r"C:\Users\satya\Desktop\python\Python for data analysis\scriptsLecture\section5\starbucks-menu-nutrition-drinks.csv")

# %%
drink.head()
# Out:
#                                           Unnamed: 0 Calories Fat (g)  \
# 0           Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                   Ombré Pink Drink        -       -
# 2                                         Pink Drink        -       -
# 3     Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4  Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
#
#   Carb. (g) Fiber (g) Protein Sodium
# 0        11         0       0     10
# 1         -         -       -      -
# 2         -         -       -      -
# 3        18         1       0     10
# 4        14         1       0     10

# %%
food = pd.read_csv(r"C:\Users\satya\Desktop\python\Python for data analysis\scriptsLecture\section5\starbucks-menu-nutrition-food.csv",encoding = 'utf-16')

# %%
food.head()
# Out:
#          Unnamed: 0   Calories   Fat (g)   Carb. (g)   Fiber (g)   Protein (g)
# 0      Chonga Bagel        300       5.0          50           3            12
# 1      8-Grain Roll        380       6.0          70           7            10
# 2  Almond Croissant        410      22.0          45           3            10
# 3     Apple Fritter        460      23.0          56           2             7
# 4  Banana Nut Bread        420      22.0          52           2             6

# %%
data = pd.concat([drink,food])
# Out:
# C:\Users\satya\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
data.shape
# Out:
# (290, 12)

# %%
data1 = pd.concat([drink,food], join = 'inner')

# %%
data1
# Out:
#                                             Unnamed: 0
# 0             Cool Lime Starbucks Refreshers™ Beverage
# 1                                     Ombré Pink Drink
# 2                                           Pink Drink
# 3       Strawberry Acai Starbucks Refreshers™ Beverage
# 4    Very Berry Hibiscus Starbucks Refreshers™ Beve...
# ..                                                 ...
# 108                 Justin's Chocolate Hazelnut Butter
# 109                     Justin's Classic Almond Butter
# 110                               Lemon Chiffon Yogurt
# 111                           Organic Avocado (Spread)
# 112                               Seasonal Fruit Blend
#
# [290 rows x 1 columns]

# %%
food.columns,drink.columns
# Out:
# (Index(['Unnamed: 0', ' Calories', ' Fat (g)', ' Carb. (g)', ' Fiber (g)',
#         ' Protein (g)'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Calories', 'Fat (g)', 'Carb. (g)', 'Fiber (g)',
#         'Protein', 'Sodium'],
#        dtype='object'))

# %%
food.columns = ['Item','Cal','Fat','Carb','Fib',"pro"]
drink.columns = ['Item','Cal','Fat','Carb','Fib',"pro",'sod']

# %%
data2 = pd.concat([food,drink],join = 'inner')

# %%
data2
# Out:
#                     Item  Cal Fat Carb Fib pro
# 0           Chonga Bagel  300   5   50   3  12
# 1           8-Grain Roll  380   6   70   7  10
# 2       Almond Croissant  410  22   45   3  10
# 3          Apple Fritter  460  23   56   2   7
# 4       Banana Nut Bread  420  22   52   2   6
# ..                   ...  ...  ..  ...  ..  ..
# 172   Chocolate Smoothie  320   5   53   8  20
# 173  Strawberry Smoothie  300   2   60   7  16
# 174           Ginger Ale    -   -    -   -   -
# 175            Lemon Ale    -   -    -   -   -
# 176    Orange Cream Soda    -   -    -   -   -
#
# [290 rows x 6 columns]

# %% [markdown]
# ## Merging

# %%
gfp = pd.read_csv(r"C:\Users\satya\Desktop\python\Python for data analysis\scriptsLecture\section5\GlobalFirePower.csv")

# %%
gfp.head()
# Out:
#          Country ISO3  Rank  Total Population  Manpower Available  \
# 0  United States  USA     1         323995528           145215000
# 1         Russia  RUS     2         142355415            70000000
# 2          China  CHN     3        1373541278           750000000
# 3          India  IND     4        1266883598           616000000
# 4         France  FRA     5          66836154            30000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 0        120025000                4220000                   2363675
# 1         47000000                1355000                   3371027
# 2        619000000               19550000                   3712500
# 3        489600000               22900000                   4207250
# 4         23750000                 775000                    387635
#
#    Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 0           1373650             990025  ...                 224792
# ...

# %%
gfp.shape
# Out:
# (133, 47)

# %%
gdp = pd.read_csv(r"C:\Users\satya\Desktop\python\Python for data analysis\scriptsLecture\section5\countryGDP.csv")

# %%
gdp.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
gdp.shape
# Out:
# (201, 4)

# %%
x = pd.merge(gdp,gfp, on = 'Country')

# %%
x.shape
# Out:
# (126, 50)

# %%
x
# Out:
#          Country Code  Population  GDP per Capita ISO3  Rank  \
# 0    Afghanistan  AFG  32526562.0      594.323081  AFG    69
# 1        Albania  ALB   2889167.0     3945.217582  ALB    90
# 2        Algeria  ALG  39666519.0     4206.031232  ALG    25
# 3         Angola  ANG  25021974.0     4101.472152  ANG    51
# 4      Argentina  ARG  43416755.0    13431.878340  ARG    35
# ..           ...  ...         ...             ...  ...   ...
# 121    Venezuela  VEN  31108083.0             NaN  VEN    45
# 122      Vietnam  VIE  91703800.0     2111.138024  VTN    16
# 123        Yemen  YEM  26832215.0     1406.291651  YEM    64
# 124       Zambia  ZAM  16211767.0     1304.879014  ZAM    85
# 125     Zimbabwe  ZIM  15602751.0      924.143819  ZIM    81
#
#      Total Population  Manpower Available  Fit-for-Service  \
# 0            33332025            14000000          8000000
# 1             3038594             1515000          1300000
# ...

# %%
y = pd.merge(gdp,gfp[["Country","ISO3","Rank","Total Population","Manpower Available"]],on="Country")

# %%
y
# Out:
#          Country Code  Population  GDP per Capita ISO3  Rank  \
# 0    Afghanistan  AFG  32526562.0      594.323081  AFG    69
# 1        Albania  ALB   2889167.0     3945.217582  ALB    90
# 2        Algeria  ALG  39666519.0     4206.031232  ALG    25
# 3         Angola  ANG  25021974.0     4101.472152  ANG    51
# 4      Argentina  ARG  43416755.0    13431.878340  ARG    35
# ..           ...  ...         ...             ...  ...   ...
# 121    Venezuela  VEN  31108083.0             NaN  VEN    45
# 122      Vietnam  VIE  91703800.0     2111.138024  VTN    16
# 123        Yemen  YEM  26832215.0     1406.291651  YEM    64
# 124       Zambia  ZAM  16211767.0     1304.879014  ZAM    85
# 125     Zimbabwe  ZIM  15602751.0      924.143819  ZIM    81
#
#      Total Population  Manpower Available
# 0            33332025            14000000
# 1             3038594             1515000
# 2            40263711            20400000
# 3            20172332             6030000
# ...
